# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Pranil Gavade - Aspiring Data Scientist**

# %% [markdown]
# *- I'm interested in data science because I really enjoy discover new things working with data, and its fascinating that how we can predict forecast, provide recommmendation and other AI stuff.*

# %% [markdown]
# ### My code will add the numbers and display the output

# %%
3+7
# Out:
# 10

# %% [markdown]
# [Connect with me on LinkedIN](https://www.linkedin.com/in/pranil-gavade/)

# %% [markdown]
# He is GodOfCricket:
# ![alt text](https://pbs.twimg.com/profile_images/1260456676890742786/MzGhbLvr_400x400.jpg "God of Cricket")

# %% [markdown]
# ~~Its impossible!!~~
# Nothing is Impossible!!
